# %%
import os
from os import listdir
from os.path import isfile, join
import pandas as pd
mypath=r'D:\resbattery'
folders = [f for f in listdir(mypath)]
files=[f for i in folders for f in listdir(join(mypath,i)) ]
files
# folders
# Out:
# ['2017-05-12_3_6C-80per_3_6C_CH1.csv',
#  '2017-05-12_3_6C-80per_3_6C_CH2.csv',
#  '2017-05-12_3_6C-80per_3_6C_CH3.csv',
#  '2017-05-12_4C-80per_4C_CH5.csv',
#  '2017-05-12_4C-80per_4C_CH6.csv',
#  '2017-05-12_4_4C-80per_4_4C_CH7.csv',
#  '2017-05-12_4_8C-80per_4_8C_CH10.csv',
#  '2017-05-12_4_8C-80per_4_8C_CH9.csv',
#  '2017-05-12_5_4C-40per_3_6C_CH19.csv',
#  '2017-05-12_5_4C-40per_3_6C_CH20.csv',
#  '2017-05-12_5_4C-50per_3C_CH13.csv',
#  '2017-05-12_5_4C-50per_3C_CH14.csv',
#  '2017-05-12_5_4C-50per_3_6C_CH21.csv',
#  '2017-05-12_5_4C-50per_3_6C_CH22.csv',
#  '2017-05-12_5_4C-60per_3C_CH15.csv',
#  '2017-05-12_5_4C-60per_3C_CH16.csv',
#  '2017-05-12_5_4C-60per_3_6C_CH23.csv',
#  '2017-05-12_5_4C-60per_3_6C_CH24.csv',
#  '2017-05-12_5_4C-70per_3C_CH17.csv',
#  '2017-05-12_5_4C-70per_3C_CH18.csv',
#  '2017-05-12_5_4C-80per_5_4C_CH11.csv',
#  '2017-05-12_5_4C-80per_5_4C_CH12.csv',
#  '2017-05-12_6C-30per_3_6C_CH31.csv',
#  '2017-05-12_6C-30per_3_6C_CH32.csv',
# ...

# %%
len(files)
# Out:
# 140

# %%
for f in listdir(join(files[0],i)if isfile(join(mypath, f)))
# Out:
#   File "<ipython-input-21-82ce7531a1b5>", line 1
#     for f in listdir(join(files[0],i)if isfile(join(mypath, f)))
#                                                                ^
# SyntaxError: invalid syntax

# %%
file_list=list()
for dirpath,dirname,filenames in os.walk(mypath):
    print(dirpath)
    for i in filenames:
        print('**********',i,'***********')
        path=join(dirpath,i)
        data=pd.read_csv(path)
        file_list.append(data)
y=pd.concat(file_list,axis=0,ignore_index=True,sort=False)
# Out:
# D:\resbattery
# D:\resbattery\batch1
# ********** 2017-05-12_3_6C-80per_3_6C_CH1.csv ***********
# ********** 2017-05-12_3_6C-80per_3_6C_CH2.csv ***********
# ********** 2017-05-12_3_6C-80per_3_6C_CH3.csv ***********
# ********** 2017-05-12_4C-80per_4C_CH5.csv ***********
# ********** 2017-05-12_4C-80per_4C_CH6.csv ***********
# ********** 2017-05-12_4_4C-80per_4_4C_CH7.csv ***********
# ********** 2017-05-12_4_8C-80per_4_8C_CH10.csv ***********
# ********** 2017-05-12_4_8C-80per_4_8C_CH9.csv ***********
# ********** 2017-05-12_5_4C-40per_3_6C_CH19.csv ***********
# ********** 2017-05-12_5_4C-40per_3_6C_CH20.csv ***********
# ********** 2017-05-12_5_4C-50per_3C_CH13.csv ***********
# ********** 2017-05-12_5_4C-50per_3C_CH14.csv ***********
# ********** 2017-05-12_5_4C-50per_3_6C_CH21.csv ***********
# ********** 2017-05-12_5_4C-50per_3_6C_CH22.csv ***********
# ********** 2017-05-12_5_4C-60per_3C_CH15.csv ***********
# ********** 2017-05-12_5_4C-60per_3C_CH16.csv ***********
# ...

# %%
data=pd.read_csv(r'D:/resbattery/batch1/2017-05-12_3_6C-80per_3_6C_CH1.csv')
